# %%
from google.colab.patches import cv2_imshow
import cv2

image = cv2.imread("chitay.jpg")

cv2_imshow(image) #to view the palm in python
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FC1AF0AE4D0>
# -1

# %%
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
edges = cv2.Canny(gray, 50, 150,apertureSize = 3)
cv2_imshow(edges)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=259x194 at 0x7FC1AEFCEB90>
# -1

# %%
edges = cv2.bitwise_not(edges)

# %%
cv2.imwrite("palmlines.jpg", edges)
palmlines = cv2.imread("palmlines.jpg")
img = cv2.addWeighted(palmlines, 0.3, image, 0.7, 0)
cv2_imshow(img) #to view the palm in python
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FC1AEFE3990>
